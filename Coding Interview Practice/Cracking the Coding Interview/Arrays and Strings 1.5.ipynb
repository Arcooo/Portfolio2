# %% [raw]
# One Away: There are three types of edits that can be performed on strings: insert a character,
# remove a character, or replace a character. Given two strings, write a function to check if they are
# one edit (or zero edits) away.
# EXAMPLE
# pale, ple -> true
# pales, pale -> true
# pale, bale -> true
# pale, bae -> false

# %% [raw]
# Initial Thoughts
#
#
# So there are 3 things we can do. So basically we have to test each one on the input.
#
# After I finish this. You should be able to implement a count for how far apart two words are.
#
# * a note about if you go further, there has to be an order of operations of correctly changing from one string to another.
# for example, if you delete a character it could have catastrophic affects if you're reading from left to right. You might have to find the special cases like i feel like 00001 and 00010. I feel like a good question would be about reordering or swapping. for some reason im picturing this machine with two hands/pointers preordering before it goes into the machine. presorting.

# %%
class WordPlay:
    def __init__(self, s1, s2):
        self.s1 = s1
        self.s2 = s2
        
    def runOfChanges(self):
        dif = abs(len(self.s1) - len(self.s2))
        
        for each in enumerate(zip(self.s1, self.s2)):
            if (each[1][0] != each[1][1]):
                
                if(self.s2[each[0]+1] != None):
                    print('2')
                
                
                
#                 print('22')
            
            
#             count = each
#             print (each)
#             print (each[0])
#             print (each[1][0])


print(WordPlay('aa','bb').runOfChanges())
# Out:
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-119-ab6099fbb349> in <module>()
#      24
#      25
# ---> 26 print(WordPlay('aa','bb').runOfChanges())
#
# <ipython-input-119-ab6099fbb349> in runOfChanges(self)
#      10             if (each[1][0] != each[1][1]):
#      11
# ---> 12                 if(self.s2[each[0]+1] != None):
#      13                     print('2')
#      14
#
# IndexError: string index out of range

# %%
class WordPlay:
    def __init__(self, s1, s2):
        self.s1 = s1
        self.s2 = s2
        
    def MVC(self):
        dif = insDelTest(self)
        
        
        
        
        
        
        
        for each in s1:
            
        
        
#         for each in the shorter of the two. scan from left to right until it finds different characters in each string. 
#         check if the next letter is the correct letter. if not then change it. else if it is, insert/delete depending
        
        if(dif<0):
            pass
        elif(dif>0):
            pass
        else:
            pass
        
        
        
    def insDelTest(self):
        return = len(self.s1) - len(self.s2)

    def replaceTest(self):
        print('hi')
        
    def feedScanner(self, s1, s2, dif):
        if(dif<0):
            difcnt = dif
            pt1 = 0
            pt2 = 0
            
            for each in s1:
                
            
            
            pass
        elif(dif>0):
            pass
        else:
            pass
        
    
        
print(WordPlay('123','1234').insDelTest())
# Out:
# -1

# %%
# Functions

class WordPlay:
    def __init__(self, s1, s2):
        pass
    
    def oneAway(self, s1, s2):
        dif = len(s1) - len(s2)
        
        if(dif<0):
            pass
        elif(dif>0):
            pass
        else:
            pass
    def func(self, s1, s2):
        print('hi')
            
            
            
            
            
# It will take at least 1 insert
# That also means that s1 is shorter than s2
# Where do you insert it? in s1
# In the special case where e.g. "a" and "aa" where. when pointer count = 0
            for each in zip(s1,s2):
                print (each)
        
                
            pass

        elif(dif<0):
#     at least 1 delete
            pass
        elif(dif==0):
            pass
        else:
            pass
        return True
        
        
        
        
        def insDelAway():
            
        
        
        
        
        
#         def 
        
        
        
        
#         differences in Length measure
        dif = len(s1) - len(s2)
    
#     If its more than 2, then its more than one away so it's False
        if(abs(dif)>1):
            return False
        
        if(dif<0):
# It will take at least 1 insert
# That also means that s1 is shorter than s2
# Where do you insert it? in s1
# In the special case where e.g. "a" and "aa" where. when pointer count = 0
            for each in zip(s1,s2):
                print (each)
        
                
            pass

        elif(dif<0):
#     at least 1 delete
            pass
        elif(dif==0):
            pass
        else:
            pass
        return True

print(oneEditAway.oneAway("aa","aaa"))




# def oneEditAway(s1, s2):
# #     Define 3 tests

# #     Test if you need to insert a character. You need to insert a character if s1 is longer than s2
#     def insertDelTest(s1, s2):
#         dif = len(s1) - len(s2)
#         if(dif>0):
# #             it will take at least 1 insert
#             pass
#         elif(dif<0):
# #     at least 1 delete
#             pass
#         elif(dif==0):
#             pass
#         else:
#             print("error line 21")
    
#     def changeTest(s1,s2):
#         assert(len(s1)==len(s2))
        
# # changeTest('s','s')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1ad1f4e99c97> in <module>()
#      39         return True
#      40
# ---> 41 print(oneEditAway.oneAway("aa","aaa"))
#      42
#      43
#
# TypeError: oneAway() missing 1 required positional argument: 's2'
